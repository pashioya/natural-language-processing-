# %%
import spacy
import os
from spacy.matcher import Matcher

# %%
def check_word_validity(word):
    if word.is_alpha and word.text.lower() not in nlp.Defaults.stop_words:
        return True
    else:
        return False


def extract_sample_from_file(file_name, character_count, start_position=0):
    possible_encodings = ['utf-8', 'latin-1', 'windows-1252']
    unprocessed_text = ''
    for encoding in possible_encodings:
        try:
            with open(file_name, 'r', encoding=encoding) as f:
                f.seek(start_position)
                text = f.read(character_count)
                unprocessed_text += text
            doc = nlp(text)
            # Check and remove the first token if it's not a valid word
            if check_word_validity(doc[0]):
                doc = doc[1:]

            # Check and remove the last token if it's not a valid word
            if check_word_validity(doc[-1]):
                doc = doc[:-1]
            return doc, unprocessed_text
        except UnicodeDecodeError:
            continue

# %%
nlp = spacy.load('en_core_web_sm')
#  You read a small  extract of the file mobydick.txt
mobydick_sample, unprocessed_mobydick_sample = extract_sample_from_file(os.path.join("../data","mobydick.txt"), 1000, 1000)
# take a small extraact from the file ai_forecast1.txt
ai_forecast1_sample, unprocessed_ai_forecast1_sample = extract_sample_from_file(os.path.join("../data","ai_forecast1.txt"), 5000)
# take a small extraact from the file ai_forecast2.txt
ai_forecast2_sample, unprocessed_ai_forecast2_sample = extract_sample_from_file(os.path.join("../data","ai_forecast2.txt"), 5000)

# %%
# print out the grammatical structure of the sentences 
print("Mobydick POS \n")
for sentence in mobydick_sample.sents:
    print(sentence)
    for token in sentence:
        print(token.text, token.pos_)
    print('\n')
print("************************")
print("ai_forecast1 POS \n")
for sentence in ai_forecast1_sample.sents:
    print(sentence)
    for token in sentence:
        print(token.text, token.pos_)
    print('\n')
print("************************")
print("ai_forecast2 POS \n")
for sentence in ai_forecast2_sample.sents:
    print(sentence)
    for token in sentence:
        print(token.text, token.pos_)
    print('\n')
# Out:
# Mobydick POS
#
# .
# . PUNCT
#
#
# Enter Ahab; to Him, Stubb.
#
# CHAPTER 30.
# Enter VERB
# Ahab PROPN
# ; PUNCT
# to ADP
# Him PRON
# , PUNCT
# Stubb PROPN
# . PUNCT
#
#
#  SPACE
# CHAPTER NOUN
# 30 NUM
# . PUNCT
#
#
# The Pipe.
#
#
# The DET
# Pipe PROPN
# . PUNCT
#
#
#  SPACE
#
#
# CHAPTER 31.
# CHAPTER NOUN
# 31 NUM
# . PUNCT
#
#
# Queen Mab.
#
# CHAPTER 32.
# Queen PROPN
# Mab PROPN
# . PUNCT
#
#
#  SPACE
# CHAPTER PROPN
# 32 NUM
# . PUNCT
#
#
# Cetology.
#
#
# Cetology NOUN
# . PUNCT
#
#
#  SPACE
#
#
# CHAPTER 33.
# CHAPTER NOUN
# 33 NUM
# . PUNCT
#
#
# The Specksnyder.
#
#
# The DET
# Specksnyder PROPN
# . PUNCT
#
#
#  SPACE
#
#
# CHAPTER 34.
# CHAPTER NOUN
# 34 NUM
# . PUNCT
#
#
# The Cabin-Table.
#
#
# The DET
# Cabin PROPN
# - PUNCT
# Table PROPN
# . PUNCT
#
#
#  SPACE
#
#
# CHAPTER 35.
# CHAPTER NOUN
# 35 NUM
# . PUNCT
#
#
# The Mast-Head.
#
#
# The DET
# Mast PROPN
# - PUNCT
# Head PROPN
# . PUNCT
#
#
#  SPACE
#
#
# CHAPTER 36.
# CHAPTER NOUN
# 36 NUM
# . PUNCT
#
#
# The Quarter-Deck.
#
# CHAPTER 37.
# The DET
# Quarter PROPN
# - PUNCT
# Deck PROPN
# . PUNCT
#
#
#  SPACE
# CHAPTER NOUN
# 37 NUM
# . PUNCT
#
#
# Sunset.
#
# CHAPTER 38.
# Sunset PROPN
# . PUNCT
#
#
#  SPACE
# CHAPTER PROPN
# 38 NUM
# . PUNCT
#
#
# Dusk.
#
# CHAPTER 39.
# Dusk NOUN
# . PUNCT
#
#
#  SPACE
# CHAPTER NOUN
# 39 NUM
# . PUNCT
#
#
# First Night-Watch.
#
#
# First PROPN
# Night PROPN
# - PUNCT
# Watch PROPN
# . PUNCT
#
#
#  SPACE
#
#
# CHAPTER 40.
# CHAPTER NOUN
# 40 NUM
# . PUNCT
#
#
# Midnight, Forecastle.
#
#
# Midnight NOUN
# , PUNCT
# Forecastle PROPN
# . PUNCT
#
#
#  SPACE
#
#
# CHAPTER 41.
# CHAPTER NOUN
# 41 NUM
# . PUNCT
#
#
# Moby Dick.
#
#
# Moby PROPN
# Dick PROPN
# . PUNCT
#
#
#  SPACE
#
#
# CHAPTER 42.
# CHAPTER PROPN
# 42 NUM
# . PUNCT
#
#
# The Whiteness of the Whale.
#
#
# The DET
# Whiteness PROPN
# of ADP
# the DET
# Whale PROPN
# . PUNCT
#
#
#  SPACE
#
#
# CHAPTER 43.
# CHAPTER NOUN
# 43 NUM
# . PUNCT
#
#
# Hark!
#
# CHAPTER 44.
# Hark PROPN
# ! PUNCT
#
#
#  SPACE
# CHAPTER PROPN
# 44 NUM
# . PUNCT
#
#
# The Chart.
#
#
# The DET
# Chart PROPN
# . PUNCT
#
#
#  SPACE
#
#
# CHAPTER 45.
# CHAPTER NOUN
# 45 NUM
# . PUNCT
#
#
# The Affidavit.
#
#
# The DET
# Affidavit PROPN
# . PUNCT
#
#
#  SPACE
#
#
# CHAPTER 46.
# CHAPTER NOUN
# 46 NUM
# . PUNCT
#
#
# Surmises.
#
#
# Surmises NOUN
# . PUNCT
#
#
#  SPACE
#
#
# CHAPTER 47.
# CHAPTER PROPN
# 47 NUM
# . PUNCT
#
#
# The Mat-Maker.
#
#
# The DET
# Mat PROPN
# - PUNCT
# Maker PROPN
# . PUNCT
#
#
#  SPACE
#
#
# CHAPTER 48.
# CHAPTER NOUN
# 48 NUM
# . PUNCT
#
#
# The First Lowering.
#
#
# The DET
# First PROPN
# Lowering PROPN
# . PUNCT
#
#
#  SPACE
#
#
# CHAPTER 49.
# CHAPTER NOUN
# 49 NUM
# . PUNCT
#
#
# The Hyena.
#
#
# The DET
# Hyena PROPN
# . PUNCT
#
#
#  SPACE
#
#
# CHAPTER 50.
# CHAPTER NOUN
# 50 NUM
# . PUNCT
#
#
# Ahab’s Boat and Crew.
# Ahab PROPN
# ’s PART
# Boat PROPN
# and CCONJ
# Crew PROPN
# . PUNCT
#
#
# Fedallah.
#
#
# Fedallah PROPN
# . PUNCT
#
#
#  SPACE
#
#
# CHAPTER 51.
# CHAPTER NOUN
# 51 NUM
# . PUNCT
#
#
# The Spirit-Spout.
#
#
# The DET
# Spirit PROPN
# - PUNCT
# Spout PROPN
# . PUNCT
#
#
#  SPACE
#
#
# CHAPTER 52.
# CHAPTER NOUN
# 52 NUM
# . PUNCT
#
#
# The Albatross.
#
# CHAPTER 53.
# The DET
# Albatross PROPN
# . PUNCT
#
#
#  SPACE
# CHAPTER NOUN
# 53 NUM
# . PUNCT
#
#
# The Gam.
#
# CHAPTER 54.
# The DET
# Gam PROPN
# . PUNCT
#
#
#  SPACE
# CHAPTER NOUN
# 54 NUM
# . PUNCT
#
#
# The Town-Ho’s Story.
#
#
# The DET
# Town PROPN
# - PUNCT
# Ho PROPN
# ’s PART
# Story PROPN
# . PUNCT
#
#
#  SPACE
#
#
# CHAPTER 55.
# CHAPTER NOUN
# 55 NUM
# . PUNCT
#
#
# Of the Monstrous Pictures of Whales.
#
#
# Of ADP
# the DET
# Monstrous PROPN
# Pictures PROPN
# of ADP
# Whales PROPN
# . PUNCT
#
#
#  SPACE
#
#
# CHAPTER 56.
# CHAPTER PROPN
# 56 NUM
# . PUNCT
#
#
# Of the Less Erroneous Pictures of Whales, and the True
# Pictures of Whaling Scenes.
#
#
# Of ADP
# the DET
# Less ADV
# Erroneous PROPN
# Pictures PROPN
# of ADP
# Whales PROPN
# , PUNCT
# and CCONJ
# the DET
# True PROPN
#
#  SPACE
# Pictures PROPN
# of ADP
# Whaling PROPN
# Scenes PROPN
# . PUNCT
#
#
#  SPACE
#
#
# CHAPTER 57.
# CHAPTER NOUN
# 57 NUM
# . PUNCT
#
#
# Of Whales in Paint; in Teeth; in Wood; in Sheet-Iron; in
# Stone; in Mountains; in Stars.
#
#
# Of ADP
# Whales PROPN
# in ADP
# Paint PROPN
# ; PUNCT
# in ADP
# Teeth PROPN
# ; PUNCT
# in ADP
# Wood PROPN
# ; PUNCT
# in ADP
# Sheet PROPN
# - PUNCT
# Iron PROPN
# ; PUNCT
# in ADP
#
#  SPACE
# Stone PROPN
# ; PUNCT
# in ADP
# Mountains PROPN
# ; PUNCT
# in ADP
# Stars PROPN
# . PUNCT
#
#
#  SPACE
#
#
# CHAPTER 58.
# CHAPTER NOUN
# 58 NUM
# . PUNCT
#
#
# Brit.
#
# CHAP
# Brit PROPN
# . PUNCT
#
#
#  SPACE
# CHAP PROPN
#
#
# ************************
# ai_forecast1 POS
#
# Pune, India, Sept. 13, 2022 (GLOBE NEWSWIRE) --
# Pune PROPN
# , PUNCT
# India PROPN
# , PUNCT
# Sept. PROPN
# 13 NUM
# , PUNCT
# 2022 NUM
# ( PUNCT
# GLOBE PROPN
# NEWSWIRE PROPN
# ) PUNCT
# -- PUNCT
#
#
# The global AI market size is projected to grow from USD 387.45 billion in 2022 to USD 1394.30 billion in 2029 at a CAGR of 20.1% in the forecast period.
# The DET
# global ADJ
# AI PROPN
# market NOUN
# size NOUN
# is AUX
# projected VERB
# to PART
# grow VERB
# from ADP
# USD NOUN
# 387.45 NUM
# billion NUM
# in ADP
# 2022 NUM
# to ADP
# USD NOUN
# 1394.30 NUM
# billion NUM
# in ADP
# 2029 NUM
# at ADP
# a DET
# CAGR PROPN
# of ADP
# 20.1 NUM
# % NOUN
# in ADP
# the DET
# forecast NOUN
# period NOUN
# . PUNCT
#
#
# Growing investment in AI technology by enterprises of all sizes across industries to garner momentum in the next several years.
# Growing VERB
# investment NOUN
# in ADP
# AI PROPN
# technology NOUN
# by ADP
# enterprises NOUN
# of ADP
# all DET
# sizes NOUN
# across ADP
# industries NOUN
# to PART
# garner VERB
# momentum NOUN
# in ADP
# the DET
# next ADJ
# several ADJ
# years NOUN
# . PUNCT
#
#
# Fortune Business Insights published this information in its recent report, titled Artificial Intelligence Market Forecast, 2022-2029. As per the report, the global market size was USD 328.34 billion in 2021.
#
# Fortune PROPN
# Business PROPN
# Insights PROPN
# published VERB
# this DET
# information NOUN
# in ADP
# its PRON
# recent ADJ
# report NOUN
# , PUNCT
# titled VERB
# Artificial ADJ
# Intelligence PROPN
# Market PROPN
# Forecast PROPN
# , PUNCT
# 2022 NUM
# - SYM
# 2029. NOUN
# As ADP
# per ADP
# the DET
# report NOUN
# , PUNCT
# the DET
# global ADJ
# market NOUN
# size NOUN
# was AUX
# USD NOUN
# 328.34 NUM
# billion NUM
# in ADP
# 2021 NUM
# . PUNCT
#
#  SPACE
#
#
# The rising demand for artificial intelligence technology across various induce verticals such as a retail, BFSI, healthcare, food and beverages, automotive, and logistics is significantly contributing towards the growth of the global market.
#
#
# The DET
# rising VERB
# demand NOUN
# for ADP
# artificial ADJ
# intelligence NOUN
# technology NOUN
# across ADP
# various ADJ
# induce NOUN
# verticals NOUN
# such ADJ
# as ADP
# a DET
# retail NOUN
# , PUNCT
# BFSI PROPN
# , PUNCT
# healthcare NOUN
# , PUNCT
# food NOUN
# and CCONJ
# beverages NOUN
# , PUNCT
# automotive ADJ
# , PUNCT
# and CCONJ
# logistics NOUN
# is AUX
# significantly ADV
# contributing VERB
# towards ADP
# the DET
# growth NOUN
# of ADP
# the DET
# global ADJ
# market NOUN
# . PUNCT
#
#
#  SPACE
#
#
# Request a Sample Copy of the Research Report:
#
# Request VERB
# a DET
# Sample PROPN
# Copy PROPN
# of ADP
# the DET
# Research PROPN
# Report PROPN
# : PUNCT
#
#  SPACE
#
#
# https://www.fortunebusinessinsights.com/enquiry/request-sample-pdf/artificial-intelligence-market-100114
#
# Microsoft accelerates industry cloud strategy for healthcare with the acquisition of Nuance
#
# April 12, 2021 | Microsoft News Center
#
# Share on Facebook (opens new window)
#
# https://www.fortunebusinessinsights.com/enquiry/request-sample-pdf/artificial-intelligence-market-100114 NOUN
#
#
#  SPACE
# Microsoft PROPN
# accelerates VERB
# industry NOUN
# cloud NOUN
# strategy NOUN
# for ADP
# healthcare NOUN
# with ADP
# the DET
# acquisition NOUN
# of ADP
# Nuance PROPN
#
#
#  SPACE
# April PROPN
# 12 NUM
# , PUNCT
# 2021 NUM
# | NOUN
# Microsoft PROPN
# News PROPN
# Center PROPN
#
#
#  SPACE
# Share PROPN
# on ADP
# Facebook PROPN
# ( PUNCT
# opens VERB
# new ADJ
# window NOUN
# ) PUNCT
#
#  SPACE
#
#
# Share on LinkedIn (opens new window)
#
#     Share on Twitter (opens new window)
#
#
# Share NOUN
# on ADP
# LinkedIn PROPN
# ( PUNCT
# opens VERB
# new ADJ
# window NOUN
# ) PUNCT
#
#
#      SPACE
# Share PROPN
# on ADP
# Twitter PROPN
# ( PUNCT
# opens VERB
# new ADJ
# window NOUN
# ) PUNCT
#
#
#  SPACE
#
#
# Acquisition will combine solutions and expertise to deliver new cloud and AI capabilities across healthcare and other industries
#
# Microsoft and Nuance logos
#
# REDMOND, Wash., and BURLINGTON, Mass.
# Acquisition PROPN
# will AUX
# combine VERB
# solutions NOUN
# and CCONJ
# expertise NOUN
# to PART
# deliver VERB
# new ADJ
# cloud NOUN
# and CCONJ
# AI PROPN
# capabilities NOUN
# across ADP
# healthcare NOUN
# and CCONJ
# other ADJ
# industries NOUN
#
#
#  SPACE
# Microsoft PROPN
# and CCONJ
# Nuance PROPN
# logos NOUN
#
#
#  SPACE
# REDMOND PROPN
# , PUNCT
# Wash. PROPN
# , PUNCT
# and CCONJ
# BURLINGTON PROPN
# , PUNCT
# Mass. PROPN
#
#
#  April 12, 2021 
#  PROPN
# April PROPN
# 12 NUM
# , PUNCT
# 2021 NUM
#  PROPN
#
#
# Microsoft Corp (Nasdaq: MSFT) and Nuance Communications, Inc. (Nasdaq: NUAN) today announced they have entered into a definitive agreement under which Microsoft will acquire Nuance for $56.00 per share, implying a 23% premium to the closing price of Nuance on Friday, April 9, in an all-cash transaction valued at $19.7 billion, inclusive of Nuances net debt.
# Microsoft PROPN
# Corp PROPN
# ( PUNCT
# Nasdaq PROPN
# : PUNCT
# MSFT PROPN
# ) PUNCT
# and CCONJ
# Nuance PROPN
# Communications PROPN
# , PUNCT
# Inc. PROPN
# ( PUNCT
# Nasdaq PROPN
# : PUNCT
# NUAN PROPN
# ) PUNCT
# today NOUN
# announced VERB
# they PRON
# have AUX
# entered VERB
# into ADP
# a DET
# definitive ADJ
# agreement NOUN
# under ADP
# which PRON
# Microsoft PROPN
# will AUX
# acquire VERB
# Nuance PROPN
# for ADP
# $ SYM
# 56.00 NUM
# per ADP
# share NOUN
# , PUNCT
# implying VERB
# a DET
# 23 NUM
# % NOUN
# premium NOUN
# to ADP
# the DET
# closing NOUN
# price NOUN
# of ADP
# Nuance PROPN
# on ADP
# Friday PROPN
# , PUNCT
# April PROPN
# 9 NUM
# , PUNCT
# in ADP
# an DET
# all PRON
# - PUNCT
# cash NOUN
# transaction NOUN
# valued VERB
# at ADP
# $ SYM
# 19.7 NUM
# billion NUM
# , PUNCT
# inclusive ADJ
# of ADP
# Nuances PROPN
# net ADJ
# debt NOUN
# . PUNCT
#
#
# Nuance is a trusted cloud and AI software leader representing decades of accumulated healthcare and enterprise AI experience.
# Nuance NOUN
# is AUX
# a DET
# trusted VERB
# cloud NOUN
# and CCONJ
# AI PROPN
# software NOUN
# leader NOUN
# representing VERB
# decades NOUN
# of ADP
# accumulated VERB
# healthcare NOUN
# and CCONJ
# enterprise NOUN
# AI PROPN
# experience NOUN
# . PUNCT
#
#
# Mark Benjamin will remain CEO of Nuance, reporting to Scott Guthrie, executive vice president of Cloud & AI at Microsoft.
# Mark PROPN
# Benjamin PROPN
# will AUX
# remain VERB
# CEO NOUN
# of ADP
# Nuance PROPN
# , PUNCT
# reporting VERB
# to ADP
# Scott PROPN
# Guthrie PROPN
# , PUNCT
# executive ADJ
# vice NOUN
# president NOUN
# of ADP
# Cloud PROPN
# & CCONJ
# AI PROPN
# at ADP
# Microsoft PROPN
# . PUNCT
#
#
# The transaction is intended to close this calendar year.
#
#
# The DET
# transaction NOUN
# is AUX
# intended VERB
# to PART
# close VERB
# this DET
# calendar NOUN
# year NOUN
# . PUNCT
#
#
#  SPACE
#
#
# Microsoft has accelerated its efforts to provide industry-specific cloud offerings to support customers and partners as they respond to disruption and new opportunities.
# Microsoft PROPN
# has AUX
# accelerated VERB
# its PRON
# efforts NOUN
# to PART
# provide VERB
# industry NOUN
# - PUNCT
# specific ADJ
# cloud ADJ
# offerings NOUN
# to PART
# support VERB
# customers NOUN
# and CCONJ
# partners NOUN
# as SCONJ
# they PRON
# respond VERB
# to ADP
# disruption NOUN
# and CCONJ
# new ADJ
# opportunities NOUN
# . PUNCT
#
#
# These efforts include the Microsoft Cloud for Healthcare, introduced in 2020, which aims to address the comprehensive needs of the rapidly transforming and growing healthcare industry.
# These DET
# efforts NOUN
# include VERB
# the DET
# Microsoft PROPN
# Cloud PROPN
# for ADP
# Healthcare PROPN
# , PUNCT
# introduced VERB
# in ADP
# 2020 NUM
# , PUNCT
# which PRON
# aims VERB
# to PART
# address VERB
# the DET
# comprehensive ADJ
# needs NOUN
# of ADP
# the DET
# rapidly ADV
# transforming NOUN
# and CCONJ
# growing VERB
# healthcare NOUN
# industry NOUN
# . PUNCT
#
#
# Todays acquisition announcement represents the latest step in Microsofts industry-specific cloud strategy.
#
#
# Todays NOUN
# acquisition NOUN
# announcement NOUN
# represents VERB
# the DET
# latest ADJ
# step NOUN
# in ADP
# Microsofts NOUN
# industry NOUN
# - PUNCT
# specific ADJ
# cloud NOUN
# strategy NOUN
# . PUNCT
#
#
#  SPACE
#
#
# Nuance is a pioneer and a leading provider of conversational AI and cloud-based ambient clinical intelligence for healthcare providers.
# Nuance PROPN
# is AUX
# a DET
# pioneer NOUN
# and CCONJ
# a DET
# leading VERB
# provider NOUN
# of ADP
# conversational ADJ
# AI PROPN
# and CCONJ
# cloud PROPN
# - PUNCT
# based VERB
# ambient NOUN
# clinical ADJ
# intelligence NOUN
# for ADP
# healthcare NOUN
# providers NOUN
# . PUNCT
#
#
# Nuances
# Nuances PROPN
#
#
# products include the Dragon Ambient eXperience, Dragon Medical One and PowerScribe One for radiology reporting, all leading clinical speech recognition SaaS offerings built on Microsoft Azure.
# products NOUN
# include VERB
# the DET
# Dragon PROPN
# Ambient PROPN
# eXperience PROPN
# , PUNCT
# Dragon PROPN
# Medical PROPN
# One PROPN
# and CCONJ
# PowerScribe PROPN
# One NUM
# for ADP
# radiology NOUN
# reporting NOUN
# , PUNCT
# all DET
# leading VERB
# clinical ADJ
# speech NOUN
# recognition NOUN
# SaaS PROPN
# offerings NOUN
# built VERB
# on ADP
# Microsoft PROPN
# Azure PROPN
# . PUNCT
#
#
# Nuances solutions work seamlessly with core healthcare systems, including longstanding relationships with Electronic Health Records (EHRs), to alleviate the burden of clinical documentation and empower providers to deliver better patient experiences.
# Nuances PROPN
# solutions NOUN
# work VERB
# seamlessly ADV
# with ADP
# core NOUN
# healthcare NOUN
# systems NOUN
# , PUNCT
# including VERB
# longstanding ADJ
# relationships NOUN
# with ADP
# Electronic PROPN
# Health PROPN
# Records PROPN
# ( PUNCT
# EHRs PROPN
# ) PUNCT
# , PUNCT
# to PART
# alleviate VERB
# the DET
# burden NOUN
# of ADP
# clinical ADJ
# documentation NOUN
# and CCONJ
# empower VERB
# providers NOUN
# to PART
# deliver VERB
# better ADJ
# patient ADJ
# experiences NOUN
# . PUNCT
#
#
# Nuance solutions are currently used by more than 55% of physicians and 75% of radiologists in the U.S., and used in 77% of U.S. hospitals.
# Nuance NOUN
# solutions NOUN
# are AUX
# currently ADV
# used VERB
# by ADP
# more ADJ
# than ADP
# 55 NUM
# % NOUN
# of ADP
# physicians NOUN
# and CCONJ
# 75 NUM
# % NOUN
# of ADP
# radiologists NOUN
# in ADP
# the DET
# U.S. PROPN
# , PUNCT
# and CCONJ
# used VERB
# in ADP
# 77 NUM
# % NOUN
# of ADP
# U.S. PROPN
# hospitals NOUN
# . PUNCT
#
#
# Nuances
# Nuances PROPN
#
#
# Healthcare Cloud revenue experienced 37% year-over-year growth in Nuances fiscal year 2020 (ended September 2020).
#
#
# Healthcare PROPN
# Cloud PROPN
# revenue NOUN
# experienced VERB
# 37 NUM
# % NOUN
# year NOUN
# - PUNCT
# over ADP
# - PUNCT
# year NOUN
# growth NOUN
# in ADP
# Nuances PROPN
# fiscal ADJ
# year NOUN
# 2020 NUM
# ( PUNCT
# ended VERB
# September PROPN
# 2020 NUM
# ) PUNCT
# . PUNCT
#
#
#  SPACE
#
#
# Microsofts acquisition of Nuance builds upon the successful existing partnership between the companies that was announced in 2019.
# Microsofts ADJ
# acquisition NOUN
# of ADP
# Nuance PROPN
# builds VERB
# upon SCONJ
# the DET
# successful ADJ
# existing VERB
# partnership NOUN
# between ADP
# the DET
# companies NOUN
# that PRON
# was AUX
# announced VERB
# in ADP
# 2019 NUM
# . PUNCT
#
#
# By augmenting the Microsoft Cloud for Healthcare with Nuances solutions, as well as the benefit of Nuances expertise and relationships with EHR systems providers, Microsoft will be better able to empower healthcare providers through the power of ambient clinical intelligence and other Microsoft cloud services.
# By ADP
# augmenting VERB
# the DET
# Microsoft PROPN
# Cloud PROPN
# for ADP
# Healthcare PROPN
# with ADP
# Nuances PROPN
# solutions NOUN
# , PUNCT
# as ADV
# well ADV
# as ADP
# the DET
# benefit NOUN
# of ADP
# Nuances PROPN
# expertise NOUN
# and CCONJ
# relationships NOUN
# with ADP
# EHR PROPN
# systems NOUN
# providers NOUN
# , PUNCT
# Microsoft PROPN
# will AUX
# be AUX
# better ADV
# able ADJ
# to PART
# empower VERB
# healthcare NOUN
# providers NOUN
# through ADP
# the DET
# power NOUN
# of ADP
# ambient ADJ
# clinical ADJ
# intelligence NOUN
# and CCONJ
# other ADJ
# Microsoft PROPN
# cloud NOUN
# services NOUN
# . PUNCT
#
#
# The acquisition will double Microsofts total addressable market (TAM) in the healthcare provider space, bringing the companys TAM in healthcare to nearly $500 billion.
# The DET
# acquisition NOUN
# will AUX
# double VERB
# Microsofts ADJ
# total ADJ
# addressable ADJ
# market NOUN
# ( PUNCT
# TAM PROPN
# ) PUNCT
# in ADP
# the DET
# healthcare NOUN
# provider NOUN
# space NOUN
# , PUNCT
# bringing VERB
# the DET
# companys ADJ
# TAM PROPN
# in ADP
# healthcare NOUN
# to ADP
# nearly ADV
# $ SYM
# 500 NUM
# billion NUM
# . PUNCT
#
#
# Nuance and Microsoft will deepen their existing commitments to the extended partner ecosystem, as well as the highest standards of data privacy, security and compliance.
#
#
# Nuance PROPN
# and CCONJ
# Microsoft PROPN
# will AUX
# deepen VERB
# their PRON
# existing VERB
# commitments NOUN
# to ADP
# the DET
# extended ADJ
# partner NOUN
# ecosystem NOUN
# , PUNCT
# as ADV
# well ADV
# as ADP
# the DET
# highest ADJ
# standards NOUN
# of ADP
# data NOUN
# privacy NOUN
# , PUNCT
# security NOUN
# and CCONJ
# compliance NOUN
# . PUNCT
#
#
#  SPACE
#
#
# Nuance provides the AI layer at the healthcare point of delivery and is a pioneer in the real-world application of enterprise AI, said Satya Nadella, CEO, Microsoft.
# Nuance NOUN
# provides VERB
# the DET
# AI PROPN
# layer NOUN
# at ADP
# the DET
# healthcare NOUN
# point NOUN
# of ADP
# delivery NOUN
# and CCONJ
# is AUX
# a DET
# pioneer NOUN
# in ADP
# the DET
# real ADJ
# - PUNCT
# world NOUN
# application NOUN
# of ADP
# enterprise NOUN
# AI, PROPN
# said VERB
# Satya PROPN
# Nadella PROPN
# , PUNCT
# CEO PROPN
# , PUNCT
# Microsoft PROPN
# . PUNCT
#
#
# AI is technologys most important priority, and healthcare is its most urgent application.
# AI PROPN
# is AUX
# technologys VERB
# most ADV
# important ADJ
# priority NOUN
# , PUNCT
# and CCONJ
# healthcare NOUN
# is AUX
# its PRON
# most ADV
# urgent ADJ
# application NOUN
# . PUNCT
#
#
# Together, with our partner ecosystem, we will put advanced AI solutions into the hands of professionals everywhere to drive better decision-making and create more meaningful connections, as we accelerate growth of Microsoft Cloud for Healthcare and Nuance.
#
# Beyond healthcare, Nuance provides AI expertise and customer engagement solutions across Interactive Voice Response (IVR), virtual assistants, and digital and biometric solutions to companies around the world across all industries.
# Together ADV
# , PUNCT
# with ADP
# our PRON
# partner NOUN
# ecosystem NOUN
# , PUNCT
# we PRON
# will AUX
# put VERB
# advanced ADJ
# AI PROPN
# solutions NOUN
# into ADP
# the DET
# hands NOUN
# of ADP
# professionals NOUN
# everywhere ADV
# to PART
# drive VERB
# better ADJ
# decision NOUN
# - PUNCT
# making NOUN
# and CCONJ
# create VERB
# more ADV
# meaningful ADJ
# connections NOUN
# , PUNCT
# as SCONJ
# we PRON
# accelerate VERB
# growth NOUN
# of ADP
# Microsoft PROPN
# Cloud PROPN
# for ADP
# Healthcare PROPN
# and CCONJ
# Nuance. PROPN
#
#
#  SPACE
# Beyond ADP
# healthcare NOUN
# , PUNCT
# Nuance PROPN
# provides VERB
# AI PROPN
# expertise NOUN
# and CCONJ
# customer NOUN
# engagement NOUN
# solutions NOUN
# across ADP
# Interactive PROPN
# Voice PROPN
# Response PROPN
# ( PUNCT
# IVR PROPN
# ) PUNCT
# , PUNCT
# virtual ADJ
# assistants NOUN
# , PUNCT
# and CCONJ
# digital ADJ
# and CCONJ
# biometric ADJ
# solutions NOUN
# to ADP
# companies NOUN
# around ADP
# the DET
# world NOUN
# across ADP
# all DET
# industries NOUN
# . PUNCT
#
#
# This expertise will come together with the breadth and depth of Microsofts
# This DET
# expertise NOUN
# will AUX
# come VERB
# together ADV
# with ADP
# the DET
# breadth NOUN
# and CCONJ
# depth NOUN
# of ADP
# Microsofts NOUN
#
#
# ************************
# ai_forecast2 POS
#
# The global artificial intelligence market size was $93.5 billion in 2021.
# The DET
# global ADJ
# artificial ADJ
# intelligence NOUN
# market NOUN
# size NOUN
# was AUX
# $ SYM
# 93.5 NUM
# billion NUM
# in ADP
# 2021 NUM
# . PUNCT
#
#
# And according to Grand View Research, Inc., it is projected to expand at a compound annual growth rate (CAGR) of 38.1% from 2022 to 2030.
# And CCONJ
# according VERB
# to ADP
# Grand PROPN
# View PROPN
# Research PROPN
# , PUNCT
# Inc. PROPN
# , PUNCT
# it PRON
# is AUX
# projected VERB
# to PART
# expand VERB
# at ADP
# a DET
# compound ADJ
# annual ADJ
# growth NOUN
# rate NOUN
# ( PUNCT
# CAGR PROPN
# ) PUNCT
# of ADP
# 38.1 NUM
# % NOUN
# from ADP
# 2022 NUM
# to ADP
# 2030 NUM
# . PUNCT
#
#
# The market is driven by the increasing number of connected devices, growing demand for personalized services, and a need for real-time solutions.
# The DET
# market NOUN
# is AUX
# driven VERB
# by ADP
# the DET
# increasing VERB
# number NOUN
# of ADP
# connected ADJ
# devices NOUN
# , PUNCT
# growing VERB
# demand NOUN
# for ADP
# personalized ADJ
# services NOUN
# , PUNCT
# and CCONJ
# a DET
# need NOUN
# for ADP
# real ADJ
# - PUNCT
# time NOUN
# solutions NOUN
# . PUNCT
#
#
# Additionally, advancements in cloud computing technology, along with developments in deep learning algorithms, have increased the adoption rate of AI.
#
#
# Additionally ADV
# , PUNCT
# advancements NOUN
# in ADP
# cloud ADJ
# computing NOUN
# technology NOUN
# , PUNCT
# along ADP
# with ADP
# developments NOUN
# in ADP
# deep ADJ
# learning NOUN
# algorithms NOUN
# , PUNCT
# have AUX
# increased VERB
# the DET
# adoption NOUN
# rate NOUN
# of ADP
# AI PROPN
# . PUNCT
#
#
#  SPACE
#
#
# Artificial intelligence growth can be attributed to its widespread application across diverse sectors, including healthcare, retail, and finance.
# Artificial ADJ
# intelligence NOUN
# growth NOUN
# can AUX
# be AUX
# attributed VERB
# to ADP
# its PRON
# widespread ADJ
# application NOUN
# across ADP
# diverse ADJ
# sectors NOUN
# , PUNCT
# including VERB
# healthcare NOUN
# , PUNCT
# retail NOUN
# , PUNCT
# and CCONJ
# finance NOUN
# . PUNCT
#
#
# However, some challenges must be addressed before it can reach mainstream adoption.
# However ADV
# , PUNCT
# some DET
# challenges NOUN
# must AUX
# be AUX
# addressed VERB
# before SCONJ
# it PRON
# can AUX
# reach VERB
# mainstream NOUN
# adoption NOUN
# . PUNCT
#
#
# These hurdles include high infrastructure costs associated with implementing AI systems and a lack of awareness about these technologies among businesses that could benefit from them.
#
#
# These DET
# hurdles NOUN
# include VERB
# high ADJ
# infrastructure NOUN
# costs NOUN
# associated VERB
# with ADP
# implementing VERB
# AI PROPN
# systems NOUN
# and CCONJ
# a DET
# lack NOUN
# of ADP
# awareness NOUN
# about ADP
# these DET
# technologies NOUN
# among ADP
# businesses NOUN
# that PRON
# could AUX
# benefit VERB
# from ADP
# them PRON
# . PUNCT
#
#
#  SPACE
#
#
# The artificial intelligence market is segmented based on product type, application, and region.
# The DET
# artificial ADJ
# intelligence NOUN
# market NOUN
# is AUX
# segmented VERB
# based VERB
# on ADP
# product NOUN
# type NOUN
# , PUNCT
# application NOUN
# , PUNCT
# and CCONJ
# region NOUN
# . PUNCT
#
#
# Based on product type, the market has been subdivided into service robots and software.
# Based VERB
# on ADP
# product NOUN
# type NOUN
# , PUNCT
# the DET
# market NOUN
# has AUX
# been AUX
# subdivided VERB
# into ADP
# service NOUN
# robots NOUN
# and CCONJ
# software NOUN
# . PUNCT
#
#
# The services portion accounted for around 66% share in 2016.
# The DET
# services NOUN
# portion NOUN
# accounted VERB
# for ADP
# around ADP
# 66 NUM
# % NOUN
# share NOUN
# in ADP
# 2016 NUM
# . PUNCT
#
#
# Based on application, AI has segmented into healthcare and life sciences; manufacturing and logistics; energy and utilities; banking, financial services, and insurance (BFSI); process manufacturing industries; retail and eCommerce; and agriculture and forestry sectors (agribusinesses).
#
#
# Based VERB
# on ADP
# application NOUN
# , PUNCT
# AI PROPN
# has AUX
# segmented VERB
# into ADP
# healthcare NOUN
# and CCONJ
# life NOUN
# sciences NOUN
# ; PUNCT
# manufacturing NOUN
# and CCONJ
# logistics NOUN
# ; PUNCT
# energy NOUN
# and CCONJ
# utilities NOUN
# ; PUNCT
# banking NOUN
# , PUNCT
# financial ADJ
# services NOUN
# , PUNCT
# and CCONJ
# insurance NOUN
# ( PUNCT
# BFSI PROPN
# ) PUNCT
# ; PUNCT
# process NOUN
# manufacturing NOUN
# industries NOUN
# ; PUNCT
# retail PROPN
# and CCONJ
# eCommerce PROPN
# ; PUNCT
# and CCONJ
# agriculture NOUN
# and CCONJ
# forestry NOUN
# sectors NOUN
# ( PUNCT
# agribusinesses NOUN
# ) PUNCT
# . PUNCT
#
#
#  SPACE
#
#
# The healthcare sector holds significant potential for AI across various applications.
# The DET
# healthcare NOUN
# sector NOUN
# holds VERB
# significant ADJ
# potential NOUN
# for ADP
# AI PROPN
# across ADP
# various ADJ
# applications NOUN
# . PUNCT
#
#
# This includes medical imaging analysis, molecular biology research, and drug discovery.
# This PRON
# includes VERB
# medical ADJ
# imaging NOUN
# analysis NOUN
# , PUNCT
# molecular ADJ
# biology NOUN
# research NOUN
# , PUNCT
# and CCONJ
# drug NOUN
# discovery NOUN
# . PUNCT
#
#
# Additionally, there are developments in drug optimization through predictive analytics tools provided by leading players, such as NVIDIA Corporation (NVDA), Intel Corporation (INTC), Alphabet Inc. (GOOGL), and Amazon Web Services Inc. (AMZN).
# Additionally ADV
# , PUNCT
# there PRON
# are VERB
# developments NOUN
# in ADP
# drug NOUN
# optimization NOUN
# through ADP
# predictive ADJ
# analytics NOUN
# tools NOUN
# provided VERB
# by ADP
# leading VERB
# players NOUN
# , PUNCT
# such ADJ
# as ADP
# NVIDIA PROPN
# Corporation PROPN
# ( PUNCT
# NVDA PROPN
# ) PUNCT
# , PUNCT
# Intel PROPN
# Corporation PROPN
# ( PUNCT
# INTC PROPN
# ) PUNCT
# , PUNCT
# Alphabet PROPN
# Inc. PROPN
# ( PUNCT
# GOOGL PROPN
# ) PUNCT
# , PUNCT
# and CCONJ
# Amazon PROPN
# Web PROPN
# Services PROPN
# Inc. PROPN
# ( PUNCT
# AMZN PROPN
# ) PUNCT
# . PUNCT
#
#
# This is primarily due to their high adoption rate among researchers worldwide coupled with increasing demand from patients willing to pay extra if provided better care due to side effects associated with traditional treatment methods.
#
# This PRON
# is AUX
# primarily ADV
# due ADJ
# to ADP
# their PRON
# high ADJ
# adoption NOUN
# rate NOUN
# among ADP
# researchers NOUN
# worldwide ADV
# coupled VERB
# with ADP
# increasing VERB
# demand NOUN
# from ADP
# patients NOUN
# willing ADJ
# to PART
# pay VERB
# extra ADJ
# if SCONJ
# provided VERB
# better ADJ
# care NOUN
# due ADP
# to ADP
# side NOUN
# effects NOUN
# associated VERB
# with ADP
# traditional ADJ
# treatment NOUN
# methods NOUN
# . PUNCT
#
#  SPACE
#
#
# Artificial Intelligence Market by Component Analysis
#
# AI market analysis can be segmented into hardware, software, and service components.
# Artificial PROPN
# Intelligence PROPN
# Market PROPN
# by ADP
# Component PROPN
# Analysis PROPN
#
#
#  SPACE
# AI PROPN
# market NOUN
# analysis NOUN
# can AUX
# be AUX
# segmented VERB
# into ADP
# hardware NOUN
# , PUNCT
# software NOUN
# , PUNCT
# and CCONJ
# service NOUN
# components NOUN
# . PUNCT
#
#
# The hardware segment is expected to grow at the highest CAGR during the forecast period.
# The DET
# hardware NOUN
# segment NOUN
# is AUX
# expected VERB
# to PART
# grow VERB
# at ADP
# the DET
# highest ADJ
# CAGR PROPN
# during ADP
# the DET
# forecast NOUN
# period NOUN
# . PUNCT
#
#
# The need for AI services is projected to rise as smart solutions such as virtual assistants and personalized online experiences become more widely used.
# The DET
# need NOUN
# for ADP
# AI PROPN
# services NOUN
# is AUX
# projected VERB
# to PART
# rise VERB
# as ADP
# smart ADJ
# solutions NOUN
# such ADJ
# as ADP
# virtual ADJ
# assistants NOUN
# and CCONJ
# personalized VERB
# online ADJ
# experiences NOUN
# become VERB
# more ADV
# widely ADV
# used ADJ
# . PUNCT
#
#
# These services use AI capabilities to improve business operations, such as creating automated and accurate sales projections based on client interactions and sales data.
#
# These DET
# services NOUN
# use VERB
# AI PROPN
# capabilities NOUN
# to PART
# improve VERB
# business NOUN
# operations NOUN
# , PUNCT
# such ADJ
# as ADP
# creating VERB
# automated VERB
# and CCONJ
# accurate ADJ
# sales NOUN
# projections NOUN
# based VERB
# on ADP
# client NOUN
# interactions NOUN
# and CCONJ
# sales NOUN
# data NOUN
# . PUNCT
#
#  SPACE
#
#
# Artificial Intelligence Market by Technology
#
#
# Artificial PROPN
# Intelligence PROPN
# Market PROPN
# by ADP
# Technology PROPN
#
#
#  SPACE
#
#
# There are many different types of artificial intelligence, so it can be difficult to understand the market without an overview of the technology.
# There PRON
# are VERB
# many ADJ
# different ADJ
# types NOUN
# of ADP
# artificial ADJ
# intelligence NOUN
# , PUNCT
# so SCONJ
# it PRON
# can AUX
# be AUX
# difficult ADJ
# to PART
# understand VERB
# the DET
# market NOUN
# without ADP
# an DET
# overview NOUN
# of ADP
# the DET
# technology NOUN
# . PUNCT
#
#
# The AI market is further segmented by technology.
# The DET
# AI PROPN
# market NOUN
# is AUX
# further ADV
# segmented VERB
# by ADP
# technology NOUN
# . PUNCT
#
#
# Natural language processing (NLP), machine learning, context-aware computing, computer vision, and virtual agents are some major technologies used in the AI market.
#
#
# Natural ADJ
# language NOUN
# processing NOUN
# ( PUNCT
# NLP PROPN
# ) PUNCT
# , PUNCT
# machine NOUN
# learning NOUN
# , PUNCT
# context NOUN
# - PUNCT
# aware ADJ
# computing NOUN
# , PUNCT
# computer NOUN
# vision NOUN
# , PUNCT
# and CCONJ
# virtual ADJ
# agents NOUN
# are AUX
# some DET
# major ADJ
# technologies NOUN
# used VERB
# in ADP
# the DET
# AI PROPN
# market NOUN
# . PUNCT
#
#
#  SPACE
#
#
# NLP enables a system to understand human language through various methods like speech recognition and natural language understanding.
# NLP PROPN
# enables VERB
# a DET
# system NOUN
# to PART
# understand VERB
# human ADJ
# language NOUN
# through ADP
# various ADJ
# methods NOUN
# like ADP
# speech NOUN
# recognition NOUN
# and CCONJ
# natural ADJ
# language NOUN
# understanding NOUN
# . PUNCT
#
#
# Machine learning refers to the process of developing an algorithm that can automatically learn from its experience without being explicitly programmed.
# Machine NOUN
# learning NOUN
# refers VERB
# to ADP
# the DET
# process NOUN
# of ADP
# developing VERB
# an DET
# algorithm PROPN
# that PRON
# can AUX
# automatically ADV
# learn VERB
# from ADP
# its PRON
# experience NOUN
# without ADP
# being AUX
# explicitly ADV
# programmed VERB
# . PUNCT
#
#
# Context-aware computing refers to systems that adapt their behavior according to their surroundings or environment, such as GPS location services on smartphones or self-driving cars.
#
#
# Context NOUN
# - PUNCT
# aware ADJ
# computing NOUN
# refers VERB
# to ADP
# systems NOUN
# that PRON
# adapt VERB
# their PRON
# behavior NOUN
# according VERB
# to ADP
# their PRON
# surroundings NOUN
# or CCONJ
# environment NOUN
# , PUNCT
# such ADJ
# as ADP
# GPS PROPN
# location NOUN
# services NOUN
# on ADP
# smartphones NOUN
# or CCONJ
# self NOUN
# - PUNCT
# driving VERB
# cars NOUN
# . PUNCT
#
#
#  SPACE
#
#
# Computer vision refers to techniques used to process images for perception tasks, such as facial recognition, which plays a role in self-driving cars that can detect pedestrians at night in low visibility conditions.
#
# Computer NOUN
# vision NOUN
# refers VERB
# to ADP
# techniques NOUN
# used VERB
# to PART
# process VERB
# images NOUN
# for ADP
# perception NOUN
# tasks NOUN
# , PUNCT
# such ADJ
# as ADP
# facial ADJ
# recognition NOUN
# , PUNCT
# which PRON
# plays VERB
# a DET
# role NOUN
# in ADP
# self NOUN
# - PUNCT
# driving VERB
# cars NOUN
# that PRON
# can AUX
# detect VERB
# pedestrians NOUN
# at ADP
# night NOUN
# in ADP
# low ADJ
# visibility NOUN
# conditions NOUN
# . PUNCT
#
#  SPACE
#
#
# Artificial Intelligence Market by End-User Industry
#
#
# Artificial PROPN
# Intelligence PROPN
# Market PROPN
# by ADP
# End PROPN
# - PUNCT
# User PROPN
# Industry PROPN
#
#
#  SPACE
#
#
# The AI market is segmented by end-user industry into retail, healthcare and life sciences, automotive and transportation, BFSI, consumer goods and retail, manufacturing, media and entertainment, agriculture and food, and energy and utilities.
#
#
# The DET
# AI PROPN
# market NOUN
# is AUX
# segmented VERB
# by ADP
# end NOUN
# - PUNCT
# user NOUN
# industry NOUN
# into ADP
# retail ADJ
# , PUNCT
# healthcare NOUN
# and CCONJ
# life NOUN
# sciences PROPN
# , PUNCT
# automotive ADJ
# and CCONJ
# transportation NOUN
# , PUNCT
# BFSI PROPN
# , PUNCT
# consumer NOUN
# goods NOUN
# and CCONJ
# retail NOUN
# , PUNCT
# manufacturing NOUN
# , PUNCT
# media NOUN
# and CCONJ
# entertainment NOUN
# , PUNCT
# agriculture NOUN
# and CCONJ
# food NOUN
# , PUNCT
# and CCONJ
# energy NOUN
# and CCONJ
# utilities NOUN
# . PUNCT
#
#
#  SPACE
#
#
# The retail sector accounted for one of the largest shares of the AI market in 2020.
# The DET
# retail ADJ
# sector NOUN
# accounted VERB
# for ADP
# one NUM
# of ADP
# the DET
# largest ADJ
# shares NOUN
# of ADP
# the DET
# AI PROPN
# market NOUN
# in ADP
# 2020 NUM
# . PUNCT
#
#
# This can be attributed to the rise in smartphone usage across the globe, as well as an increase in the use of smart devices.
# This PRON
# can AUX
# be AUX
# attributed VERB
# to ADP
# the DET
# rise NOUN
# in ADP
# smartphone ADJ
# usage NOUN
# across ADP
# the DET
# globe NOUN
# , PUNCT
# as ADV
# well ADV
# as ADP
# an DET
# increase NOUN
# in ADP
# the DET
# use NOUN
# of ADP
# smart ADJ
# devices NOUN
# . PUNCT
#
#
# Smartphones have also increased the demand for mobile commerce platforms, such as the customized CoverGirl app.
# Smartphones NOUN
# have AUX
# also ADV
# increased VERB
# the DET
# demand NOUN
# for ADP
# mobile ADJ
# commerce NOUN
# platforms NOUN
# , PUNCT
# such ADJ
# as ADP
# the DET
# customized VERB
# CoverGirl PROPN
# app NOUN
# . PUNCT
#
#
# The app employs predictive analytics software and applies real-time data to deliver personalized experiences to customers based on their preferences.
#
#
# The DET
# app NOUN
# employs VERB
# predictive ADJ
# analytics NOUN
# software NOUN
# and CCONJ
# applies VERB
# real ADJ
# - PUNCT
# time NOUN
# data NOUN
# to PART
# deliver VERB
# personalized VERB
# experiences NOUN
# to ADP
# customers NOUN
# based VERB
# on ADP
# their PRON
# preferences NOUN
# . PUNCT
#
#
#  SPACE
#
#
# The automotive industry also accounted for a sizable share of the global artificial intelligence market.
# The DET
# automotive ADJ
# industry NOUN
# also ADV
# accounted VERB
# for ADP
# a DET
# sizable ADJ
# share NOUN
# of ADP
# the DET
# global ADJ
# artificial ADJ
# intelligence NOUN
# market NOUN
# . PUNCT
#
#
# This can be attributed to the increased adoption of self-driving vehicles globally.
# This PRON
# can AUX
# be AUX
# attributed VERB
# to ADP
# the DET
# increased VERB
# adoption NOUN
# of ADP
# self NOUN
# - PUNCT
# driving VERB
# vehicles NOUN
# globally ADV
# . PUNCT
#
#
# This has also led to more adoption of intelligent transportation systems, such as electronic toll collection, ramp meters, red light cameras, traffic signal coordination, transit signal priority, and traveler information systems.
#
#
# This PRON
# has AUX
# also ADV
# led VERB
# to ADP
# more ADJ
# adoption NOUN
# of ADP
# intelligent ADJ
# transportation NOUN
# systems NOUN
# , PUNCT
# such ADJ
# as ADP
# electronic ADJ
# toll NOUN
# collection NOUN
# , PUNCT
# ramp NOUN
# meters NOUN
# , PUNCT
# red ADJ
# light NOUN
# cameras NOUN
# , PUNCT
# traffic NOUN
# signal NOUN
# coordination NOUN
# , PUNCT
# transit NOUN
# signal NOUN
# priority NOUN
# , PUNCT
# and CCONJ
# traveler NOUN
# information NOUN
# systems NOUN
# . PUNCT
#
#
#  SPACE
#
#
# The healthcare and life sciences segment is ex
# The DET
# healthcare NOUN
# and CCONJ
# life NOUN
# sciences NOUN
# segment NOUN
# is AUX
# ex NOUN

# %%
# Get the named entities from the samples

# Print named entities
print("MobyDick Named Entities:")
for ent in mobydick_sample.ents:
    print(f"{ent.text} ({ent.label_})")
print("************************")
# Out:
# MobyDick Named Entities:
# Ahab (PERSON)
# CHAPTER 30 (LAW)
# Pipe (FAC)
# CHAPTER 31 (LAW)
# Queen Mab (PERSON)
# CHAPTER 32 (LAW)
# CHAPTER 33 (LAW)
# Specksnyder (ORG)
# CHAPTER 34 (LAW)
# The Cabin-Table (ORG)
# CHAPTER 35 (LAW)
# CHAPTER 36 (LAW)
# The Quarter-Deck (ORG)
# CHAPTER 37 (LAW)
# CHAPTER 38 (LAW)
# CHAPTER 39 (LAW)
# First Night-Watch (ORG)
# CHAPTER 40 (LAW)
# Midnight (TIME)
# Forecastle (PERSON)
# CHAPTER 41 (LAW)
# Moby Dick (PERSON)
# CHAPTER 42 (LAW)
# The Whiteness of the Whale (ORG)
# CHAPTER 43 (LAW)
# CHAPTER 44 (LAW)
# Chart (ORG)
# CHAPTER 45 (LAW)
# Affidavit (GPE)
# CHAPTER 46 (LAW)
# CHAPTER 47 (LAW)
# The Mat-Maker (ORG)
# CHAPTER 48 (LAW)
# The First Lowering (ORG)
# CHAPTER 49 (LAW)
# Hyena (GPE)
# CHAPTER 50 (LAW)
# Ahab’s Boat (PERSON)
# Crew (PERSON)
# Fedallah (PERSON)
# CHAPTER 51 (LAW)
# CHAPTER 52 (LAW)
# Albatross (LOC)
# CHAPTER 53 (LAW)
# CHAPTER 54 (LAW)
# The Town-Ho’s Story (ORG)
# CHAPTER 55 (LAW)
# the Monstrous Pictures of Whales (ORG)
# CHAPTER 56 (LAW)
# the Less Erroneous Pictures (ORG)
# the True
# Pictures of Whaling Scenes (ORG)
# CHAPTER 57 (LAW)
# Teeth (GPE)
# Wood (GPE)
# Sheet-Iron (ORG)
# Stone (ORG)
# Mountains (ORG)
# CHAPTER 58 (LAW)
# ************************

# %%
# Get the named entities from the samples

# Print named entities
print("ai_forecast1 Named Entities:")
for ent in ai_forecast1_sample.ents:
    print(f"{ent.text} ({ent.label_})")
print("************************")
# Out:
# ai_forecast1 Named Entities:
# Sept. 13, 2022 (DATE)
# GLOBE NEWSWIRE (ORG)
# AI (ORG)
# USD 387.45 billion (MONEY)
# 2022 (DATE)
# USD 1394.30 billion (MONEY)
# 2029 (DATE)
# 20.1% (PERCENT)
# AI (ORG)
# the next several years (DATE)
# Fortune Business Insights (ORG)
# 2022-2029. (DATE)
# USD 328.34 billion (MONEY)
# 2021 (DATE)
# BFSI (ORG)
# Request a Sample Copy of the Research Report (WORK_OF_ART)
# Microsoft (ORG)
# Nuance (GPE)
# April 12 (DATE)
# 2021 (DATE)
# Microsoft News Center
#
# Share on Facebook (ORG)
# LinkedIn (GPE)
# Twitter (PERSON)
# AI (ORG)
# Microsoft (ORG)
# Nuance (GPE)
# REDMOND (GPE)
# Wash. (GPE)
# BURLINGTON (GPE)
# Mass. (GPE)
# April 12 (DATE)
# 2021 (DATE)
# Microsoft Corp (ORG)
# Nuance Communications, Inc. (ORG)
# today (DATE)
# Microsoft (ORG)
# Nuance (GPE)
# 56.00 (MONEY)
# 23% (PERCENT)
# Nuance (GPE)
# Friday, April 9 (DATE)
# $19.7 billion (MONEY)
# Nuances (ORG)
# AI (ORG)
# decades (DATE)
# AI (ORG)
# Mark Benjamin (PERSON)
# Nuance (GPE)
# Scott Guthrie (PERSON)
# Cloud & AI (ORG)
# Microsoft (ORG)
# this calendar year (DATE)
# Microsoft (ORG)
# the Microsoft Cloud for (ORG)
# Healthcare (ORG)
# 2020 (DATE)
# Nuance (WORK_OF_ART)
# AI (ORG)
# the Dragon Ambient eXperience (ORG)
# Dragon Medical One (ORG)
# PowerScribe (ORG)
# Microsoft Azure (ORG)
# Electronic Health Records (ORG)
# more than 55% (PERCENT)
# 75% (PERCENT)
# U.S. (GPE)
# 77% (PERCENT)
# U.S. (GPE)
# Healthcare Cloud (PERSON)
# 37% (PERCENT)
# year-over-year (DATE)
# Nuances (GPE)
# fiscal year 2020 (DATE)
# September 2020 (DATE)
# Nuance (GPE)
# 2019 (DATE)
# the Microsoft Cloud for (ORG)
# Healthcare (ORG)
# Nuances (ORG)
# Nuances (ORG)
# Microsoft (ORG)
# Microsoft (ORG)
# TAM (ORG)
# TAM (ORG)
# nearly $500 billion (MONEY)
# Microsoft (ORG)
# AI (ORG)
# Satya Nadella (PERSON)
# Microsoft (ORG)
# AI (PERSON)
# AI (ORG)
# Microsoft Cloud (ORG)
# Healthcare (ORG)
# Nuance (GPE)
# AI (ORG)
# Interactive Voice Response (ORG)
# IVR (ORG)
# ************************

# %%
# Get the named entities from the samples

# Print named entities
print("ai_forecast2 Named Entities:")
for ent in ai_forecast2_sample.ents:
    print(f"{ent.text} ({ent.label_})")
print("************************")
# Out:
# ai_forecast2 Named Entities:
# $93.5 billion (MONEY)
# 2021 (DATE)
# Grand View Research, Inc. (ORG)
# annual (DATE)
# 38.1% (PERCENT)
# 2022 (DATE)
# 2030 (DATE)
# AI (ORG)
# AI (ORG)
# around 66% (PERCENT)
# 2016 (DATE)
# AI (ORG)
# eCommerce (PRODUCT)
# AI (ORG)
# NVIDIA Corporation (ORG)
# NVDA (ORG)
# Intel Corporation (ORG)
# Alphabet Inc. (ORG)
# Amazon Web Services Inc. (ORG)
# Artificial Intelligence Market by Component Analysis (ORG)
# AI (ORG)
# AI (ORG)
# Artificial Intelligence Market by Technology
#
#  (ORG)
# AI (ORG)
# NLP (ORG)
# AI (GPE)
# NLP (ORG)
# night (TIME)
# Artificial Intelligence Market by End-User Industry
#
#  (ORG)
# AI (ORG)
# BFSI (ORG)
# AI (ORG)
# 2020 (DATE)
# CoverGirl (ORG)
# ************************

# %%
# You also let Spacy explain the meaning of the grammar and the part-of speech tags.
matcher = Matcher(nlp.vocab)

# Task 1: Look for "Artificial Intelligence" in the Key Market Insights text
pattern_ai = [{"LOWER": "artificial"}, {"LOWER": "intelligence"}]
matcher.add("AI_MATCH", [pattern_ai])

# Task 2: Find "AI" followed by a verb
pattern_ai_verb = [{"LOWER": "ai"}, {"POS": "VERB"}]
matcher.add("AI_VERB_MATCH", [pattern_ai_verb])

# Task 3: Find numbers followed by a %
pattern_percent = [{"LIKE_NUM": True}, {"TEXT": "%"}]
matcher.add("PERCENT_MATCH", [pattern_percent])

# Task 4: Find company names (using a simplified example)
pattern_company = [{"ENT_TYPE": "ORG"}]
matcher.add("COMPANY_MATCH", [pattern_company])

# Find matches in the document
moby_dick_matches = matcher(mobydick_sample)
ai_forecast_1_matches = matcher(ai_forecast1_sample)
ai_forecast_2_matches = matcher(ai_forecast2_sample)

# %%
# Display matches
for match_id, start, end in moby_dick_matches:
    match_text = mobydick_sample[start:end].text
    print(f"Matched '{match_text}' (pattern: {nlp.vocab.strings[match_id]})")
# Out:
# Matched 'Specksnyder' (pattern: COMPANY_MATCH)
# Matched 'The' (pattern: COMPANY_MATCH)
# Matched 'Cabin' (pattern: COMPANY_MATCH)
# Matched '-' (pattern: COMPANY_MATCH)
# Matched 'Table' (pattern: COMPANY_MATCH)
# Matched 'The' (pattern: COMPANY_MATCH)
# Matched 'Quarter' (pattern: COMPANY_MATCH)
# Matched '-' (pattern: COMPANY_MATCH)
# Matched 'Deck' (pattern: COMPANY_MATCH)
# Matched 'First' (pattern: COMPANY_MATCH)
# Matched 'Night' (pattern: COMPANY_MATCH)
# Matched '-' (pattern: COMPANY_MATCH)
# Matched 'Watch' (pattern: COMPANY_MATCH)
# Matched 'The' (pattern: COMPANY_MATCH)
# Matched 'Whiteness' (pattern: COMPANY_MATCH)
# Matched 'of' (pattern: COMPANY_MATCH)
# Matched 'the' (pattern: COMPANY_MATCH)
# Matched 'Whale' (pattern: COMPANY_MATCH)
# Matched 'Chart' (pattern: COMPANY_MATCH)
# Matched 'The' (pattern: COMPANY_MATCH)
# Matched 'Mat' (pattern: COMPANY_MATCH)
# Matched '-' (pattern: COMPANY_MATCH)
# Matched 'Maker' (pattern: COMPANY_MATCH)
# Matched 'The' (pattern: COMPANY_MATCH)
# Matched 'First' (pattern: COMPANY_MATCH)
# Matched 'Lowering' (pattern: COMPANY_MATCH)
# Matched 'The' (pattern: COMPANY_MATCH)
# Matched 'Town' (pattern: COMPANY_MATCH)
# Matched '-' (pattern: COMPANY_MATCH)
# Matched 'Ho' (pattern: COMPANY_MATCH)
# Matched '’s' (pattern: COMPANY_MATCH)
# Matched 'Story' (pattern: COMPANY_MATCH)
# Matched 'the' (pattern: COMPANY_MATCH)
# Matched 'Monstrous' (pattern: COMPANY_MATCH)
# Matched 'Pictures' (pattern: COMPANY_MATCH)
# Matched 'of' (pattern: COMPANY_MATCH)
# Matched 'Whales' (pattern: COMPANY_MATCH)
# Matched 'the' (pattern: COMPANY_MATCH)
# Matched 'Less' (pattern: COMPANY_MATCH)
# Matched 'Erroneous' (pattern: COMPANY_MATCH)
# Matched 'Pictures' (pattern: COMPANY_MATCH)
# Matched 'the' (pattern: COMPANY_MATCH)
# Matched 'True' (pattern: COMPANY_MATCH)
# Matched '
# ' (pattern: COMPANY_MATCH)
# Matched 'Pictures' (pattern: COMPANY_MATCH)
# Matched 'of' (pattern: COMPANY_MATCH)
# Matched 'Whaling' (pattern: COMPANY_MATCH)
# Matched 'Scenes' (pattern: COMPANY_MATCH)
# Matched 'Sheet' (pattern: COMPANY_MATCH)
# Matched '-' (pattern: COMPANY_MATCH)
# Matched 'Iron' (pattern: COMPANY_MATCH)
# Matched 'Stone' (pattern: COMPANY_MATCH)
# Matched 'Mountains' (pattern: COMPANY_MATCH)

# %%
# Display matches
for match_id, start, end in ai_forecast_1_matches:
    match_text = ai_forecast1_sample[start:end].text
    print(f"Matched '{match_text}' (pattern: {nlp.vocab.strings[match_id]})")
# Out:
# Matched 'GLOBE' (pattern: COMPANY_MATCH)
# Matched 'NEWSWIRE' (pattern: COMPANY_MATCH)
# Matched 'AI' (pattern: COMPANY_MATCH)
# Matched '20.1%' (pattern: PERCENT_MATCH)
# Matched 'AI' (pattern: COMPANY_MATCH)
# Matched 'Fortune' (pattern: COMPANY_MATCH)
# Matched 'Business' (pattern: COMPANY_MATCH)
# Matched 'Insights' (pattern: COMPANY_MATCH)
# Matched 'artificial intelligence' (pattern: AI_MATCH)
# Matched 'BFSI' (pattern: COMPANY_MATCH)
# Matched 'Microsoft' (pattern: COMPANY_MATCH)
# Matched 'Microsoft' (pattern: COMPANY_MATCH)
# Matched 'News' (pattern: COMPANY_MATCH)
# Matched 'Center' (pattern: COMPANY_MATCH)
# Matched '
#
# ' (pattern: COMPANY_MATCH)
# Matched 'Share' (pattern: COMPANY_MATCH)
# Matched 'on' (pattern: COMPANY_MATCH)
# Matched 'Facebook' (pattern: COMPANY_MATCH)
# Matched 'AI' (pattern: COMPANY_MATCH)
# Matched 'Microsoft' (pattern: COMPANY_MATCH)
# Matched 'Microsoft' (pattern: COMPANY_MATCH)
# Matched 'Corp' (pattern: COMPANY_MATCH)
# Matched 'Nuance' (pattern: COMPANY_MATCH)
# Matched 'Communications' (pattern: COMPANY_MATCH)
# Matched ',' (pattern: COMPANY_MATCH)
# Matched 'Inc.' (pattern: COMPANY_MATCH)
# Matched 'Microsoft' (pattern: COMPANY_MATCH)
# Matched '23%' (pattern: PERCENT_MATCH)
# Matched 'Nuances' (pattern: COMPANY_MATCH)
# Matched 'AI' (pattern: COMPANY_MATCH)
# Matched 'AI' (pattern: COMPANY_MATCH)
# Matched 'Cloud' (pattern: COMPANY_MATCH)
# Matched '&' (pattern: COMPANY_MATCH)
# Matched 'AI' (pattern: COMPANY_MATCH)
# Matched 'Microsoft' (pattern: COMPANY_MATCH)
# Matched 'Microsoft' (pattern: COMPANY_MATCH)
# Matched 'the' (pattern: COMPANY_MATCH)
# Matched 'Microsoft' (pattern: COMPANY_MATCH)
# Matched 'Cloud' (pattern: COMPANY_MATCH)
# Matched 'for' (pattern: COMPANY_MATCH)
# Matched 'Healthcare' (pattern: COMPANY_MATCH)
# Matched 'AI' (pattern: COMPANY_MATCH)
# Matched 'the' (pattern: COMPANY_MATCH)
# Matched 'Dragon' (pattern: COMPANY_MATCH)
# Matched 'Ambient' (pattern: COMPANY_MATCH)
# Matched 'eXperience' (pattern: COMPANY_MATCH)
# Matched 'Dragon' (pattern: COMPANY_MATCH)
# Matched 'Medical' (pattern: COMPANY_MATCH)
# Matched 'One' (pattern: COMPANY_MATCH)
# Matched 'PowerScribe' (pattern: COMPANY_MATCH)
# Matched 'Microsoft' (pattern: COMPANY_MATCH)
# Matched 'Azure' (pattern: COMPANY_MATCH)
# Matched 'Electronic' (pattern: COMPANY_MATCH)
# Matched 'Health' (pattern: COMPANY_MATCH)
# Matched 'Records' (pattern: COMPANY_MATCH)
# Matched '55%' (pattern: PERCENT_MATCH)
# Matched '75%' (pattern: PERCENT_MATCH)
# Matched '77%' (pattern: PERCENT_MATCH)
# Matched '37%' (pattern: PERCENT_MATCH)
# Matched 'the' (pattern: COMPANY_MATCH)
# Matched 'Microsoft' (pattern: COMPANY_MATCH)
# Matched 'Cloud' (pattern: COMPANY_MATCH)
# Matched 'for' (pattern: COMPANY_MATCH)
# Matched 'Healthcare' (pattern: COMPANY_MATCH)
# Matched 'Nuances' (pattern: COMPANY_MATCH)
# Matched 'Nuances' (pattern: COMPANY_MATCH)
# Matched 'Microsoft' (pattern: COMPANY_MATCH)
# Matched 'Microsoft' (pattern: COMPANY_MATCH)
# Matched 'TAM' (pattern: COMPANY_MATCH)
# Matched 'TAM' (pattern: COMPANY_MATCH)
# Matched 'Microsoft' (pattern: COMPANY_MATCH)
# Matched 'AI' (pattern: COMPANY_MATCH)
# Matched 'Microsoft' (pattern: COMPANY_MATCH)
# Matched 'AI' (pattern: COMPANY_MATCH)
# Matched 'Microsoft' (pattern: COMPANY_MATCH)
# Matched 'Cloud' (pattern: COMPANY_MATCH)
# Matched 'Healthcare' (pattern: COMPANY_MATCH)
# Matched 'AI' (pattern: COMPANY_MATCH)
# Matched 'Interactive' (pattern: COMPANY_MATCH)
# Matched 'Voice' (pattern: COMPANY_MATCH)
# Matched 'Response' (pattern: COMPANY_MATCH)
# Matched 'IVR' (pattern: COMPANY_MATCH)

# %%
# Display matches
for match_id, start, end in ai_forecast_2_matches:
    match_text = ai_forecast2_sample[start:end].text
    print(f"Matched '{match_text}' (pattern: {nlp.vocab.strings[match_id]})")
# Out:
# Matched 'artificial intelligence' (pattern: AI_MATCH)
# Matched 'Grand' (pattern: COMPANY_MATCH)
# Matched 'View' (pattern: COMPANY_MATCH)
# Matched 'Research' (pattern: COMPANY_MATCH)
# Matched ',' (pattern: COMPANY_MATCH)
# Matched 'Inc.' (pattern: COMPANY_MATCH)
# Matched '38.1%' (pattern: PERCENT_MATCH)
# Matched 'AI' (pattern: COMPANY_MATCH)
# Matched 'Artificial intelligence' (pattern: AI_MATCH)
# Matched 'AI' (pattern: COMPANY_MATCH)
# Matched 'artificial intelligence' (pattern: AI_MATCH)
# Matched '66%' (pattern: PERCENT_MATCH)
# Matched 'AI' (pattern: COMPANY_MATCH)
# Matched 'AI' (pattern: COMPANY_MATCH)
# Matched 'NVIDIA' (pattern: COMPANY_MATCH)
# Matched 'Corporation' (pattern: COMPANY_MATCH)
# Matched 'NVDA' (pattern: COMPANY_MATCH)
# Matched 'Intel' (pattern: COMPANY_MATCH)
# Matched 'Corporation' (pattern: COMPANY_MATCH)
# Matched 'Alphabet' (pattern: COMPANY_MATCH)
# Matched 'Inc.' (pattern: COMPANY_MATCH)
# Matched 'Amazon' (pattern: COMPANY_MATCH)
# Matched 'Web' (pattern: COMPANY_MATCH)
# Matched 'Services' (pattern: COMPANY_MATCH)
# Matched 'Inc.' (pattern: COMPANY_MATCH)
# Matched 'Artificial' (pattern: COMPANY_MATCH)
# Matched 'Artificial Intelligence' (pattern: AI_MATCH)
# Matched 'Intelligence' (pattern: COMPANY_MATCH)
# Matched 'Market' (pattern: COMPANY_MATCH)
# Matched 'by' (pattern: COMPANY_MATCH)
# Matched 'Component' (pattern: COMPANY_MATCH)
# Matched 'Analysis' (pattern: COMPANY_MATCH)
# Matched 'AI' (pattern: COMPANY_MATCH)
# Matched 'AI' (pattern: COMPANY_MATCH)
# Matched 'Artificial' (pattern: COMPANY_MATCH)
# Matched 'Artificial Intelligence' (pattern: AI_MATCH)
# Matched 'Intelligence' (pattern: COMPANY_MATCH)
# Matched 'Market' (pattern: COMPANY_MATCH)
# Matched 'by' (pattern: COMPANY_MATCH)
# Matched 'Technology' (pattern: COMPANY_MATCH)
# Matched '
#
# ' (pattern: COMPANY_MATCH)
# Matched 'artificial intelligence' (pattern: AI_MATCH)
# Matched 'AI' (pattern: COMPANY_MATCH)
# Matched 'NLP' (pattern: COMPANY_MATCH)
# Matched 'NLP' (pattern: COMPANY_MATCH)
# Matched 'Artificial' (pattern: COMPANY_MATCH)
# Matched 'Artificial Intelligence' (pattern: AI_MATCH)
# Matched 'Intelligence' (pattern: COMPANY_MATCH)
# Matched 'Market' (pattern: COMPANY_MATCH)
# Matched 'by' (pattern: COMPANY_MATCH)
# Matched 'End' (pattern: COMPANY_MATCH)
# Matched '-' (pattern: COMPANY_MATCH)
# Matched 'User' (pattern: COMPANY_MATCH)
# Matched 'Industry' (pattern: COMPANY_MATCH)
# Matched '
#
# ' (pattern: COMPANY_MATCH)
# Matched 'AI' (pattern: COMPANY_MATCH)
# Matched 'BFSI' (pattern: COMPANY_MATCH)
# Matched 'AI' (pattern: COMPANY_MATCH)
# Matched 'CoverGirl' (pattern: COMPANY_MATCH)
# Matched 'artificial intelligence' (pattern: AI_MATCH)
